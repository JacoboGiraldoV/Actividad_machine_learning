# %% [markdown]
# # Jacobo Giraldo Valencia
#
# # Comenzamos importando las librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.gridspec as gridspec
import scipy.stats as stats
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score
from IPython.display import Image as PImage

# %%
#Importar el archivo csv
ds = pd.read_csv("train.csv")
#Ver la cabecera de los datos
ds.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Ver las columnas que contiene el data set
ds.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# Se consultan cunatas filas y columnas contiene el dataset

ds.shape
# Out:
# (1460, 81)

# %%
#Habilitar para ver todas las filas y columnas

pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
#Ver la cola de los datos

ds.tail(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#Mostrar resumen por columnas de cuantos resgitros tiene y tipo de datos 

ds.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# Heating           object
# HeatingQC         object
# CentralAir        object
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# ...

# %%
# Validamos que columnas contiene valores nulos

ds.isnull().any()
# Out:
# Id               False
# MSSubClass       False
# MSZoning         False
# LotFrontage       True
# LotArea          False
# Street           False
# Alley             True
# LotShape         False
# LandContour      False
# Utilities        False
# LotConfig        False
# LandSlope        False
# Neighborhood     False
# Condition1       False
# Condition2       False
# BldgType         False
# HouseStyle       False
# OverallQual      False
# OverallCond      False
# YearBuilt        False
# YearRemodAdd     False
# RoofStyle        False
# RoofMatl         False
# Exterior1st      False
# Exterior2nd      False
# MasVnrType        True
# MasVnrArea        True
# ExterQual        False
# ExterCond        False
# Foundation       False
# BsmtQual          True
# BsmtCond          True
# BsmtExposure      True
# BsmtFinType1      True
# BsmtFinSF1       False
# BsmtFinType2      True
# BsmtFinSF2       False
# BsmtUnfSF        False
# TotalBsmtSF      False
# Heating          False
# ...

# %%
#Contar cuantos valores nulos hay por columna
ds.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
#Reemplazar valor nan

ds['LotFrontage'] = ds['LotFrontage'].fillna((ds['LotFrontage'].mean()))
ds['MasVnrArea'] = ds['MasVnrArea'].fillna((ds['MasVnrArea'].mean()))
ds['GarageYrBlt'] = ds['GarageYrBlt'].fillna((ds['GarageYrBlt'].mean()))

# %%
#Resumen de algunos valores como Maximos, Minimos, promedio, desviacion estandar y algunos valores de percentil.
ds.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    22.024023    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    60.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    70.049958    9478.500000     6.000000     5.000000
# 75%      70.000000    79.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   180.569112   456.098091   161.319273
# ...

# %%
Corr_vars = ds.corr()
Corr_vars
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.357056 -0.139781     0.032628    -0.059316
# LotFrontage     -0.357056     1.000000  0.306795     0.234196    -0.052820
# LotArea         -0.139781     0.306795  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.234196  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.052820 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.117598  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.082746  0.013788     0.550684     0.073741
# MasVnrArea       0.022895     0.179283  0.103960     0.410238    -0.127788
# BsmtFinSF1      -0.069836     0.215828  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649     0.043340  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.122156 -0.002618     0.308159    -0.136841
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.subplots(figsize=(30,40))
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
sns.heatmap(Corr_vars, annot=True)
plt.show()

# %%
NAN_Columns=[]
i=-1
for a in ds.isnull().sum():
    i+=1
    if a!=0:
        print(ds.columns[i],a)
        NAN_Columns.append(ds.columns[i])

# %%
ds_n = ds.loc[:,["TotRmsAbvGrd","GarageArea", "GarageCars","OverallCond","PoolArea","OverallQual","LotArea", "TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "TotRmsAbvGrd", "Fireplaces", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch", "SalePrice"]]

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)
dsn_f = clean_dataset(ds_n)

# %%
dsn_f.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Creamos variable binaria

# %%
dsn_f["SalePriceBinary"] = np.where(dsn_f['SalePrice']>214000.000000 , 1, 0)
dsn_f.SalePriceBinary.describe()
# Out:
# count    1460.000000
# mean        0.247945
# std         0.431968
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: SalePriceBinary, dtype: float64

# %% [markdown]
# # Matriz de correlación
# Podemos ver que en la matriz de correlacion casi todos los parametros tienden a tener una correlación positiva con la variable binaria

# %%
k=1
corr_mat = dsn_f.corr()
f, ax = plt.subplots(figsize=(12, 9))
heatm = sns.heatmap(corr_mat, vmax=0.9, square=True, cmap = 'mako_r');
heatm.text(15, 20, 'Figure {}'.format(k),fontsize=16)
k=k+1

# %% [raw]
# Podemos observar que las variables que tienes mayor correlacion con la variable binaria (SalePriceBinary) son SalePrice y OverallQual

# %%
corr_feat = dsn_f.corr().nlargest(5,"SalePriceBinary")["SalePriceBinary"].index
c_map = np.corrcoef(dsn_f[corr_feat].values.T)
mask = np.zeros_like(c_map,dtype=bool)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(20,10))
sns.heatmap(c_map,
            annot=True,
            fmt=".3f",
            annot_kws = {"size":12},
            cmap=sns.cubehelix_palette(),
            xticklabels = corr_feat.values,
            yticklabels = corr_feat.values,
            mask=mask)
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import norm

# %% [markdown]
# Podemos ver que la variables binaria (SalePriceBinary) es positivamente simetrica

# %%
sns.distplot(dsn_f['SalePriceBinary'], color= 'blue', fit=norm);
plt.title('Figure {}'.format(k), y=-0.5, fontsize = 20)
print("Skewness: %f" % dsn_f['SalePriceBinary'].skew())
print("Kurtosis: %f" % dsn_f['SalePriceBinary'].kurt())
# Out:
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Skewness: 1.168608
# Kurtosis: -0.635227

# %%
fig = plt.figure(constrained_layout=True, figsize=(12,8))
grid = gridspec.GridSpec(ncols=3, nrows=4, figure=fig)

ax1 = fig.add_subplot(grid[0,:])
sns.distplot(dsn_f["SalePriceBinary"],ax=ax1)
ax1.set_title("Histrogram of SalePrice")

ax2 = fig.add_subplot(grid[2:,:2])
stats.probplot(dsn_f["SalePriceBinary"],plot=ax2)
ax2.set_title("QQplot of SalePrice")

ax3 = fig.add_subplot(grid[2:,2])
sns.boxplot(dsn_f["SalePriceBinary"],ax=ax3,orient="v")
ax3.set_title("Boxplot of SalePriceBinary")
plt.show()
# Out:
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
y_train = dsn_f['SalePriceBinary'].astype("int")
x_train = dsn_f.loc[:,["TotRmsAbvGrd","GarageArea", "GarageCars","OverallCond","PoolArea","OverallQual","LotArea", "TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "TotRmsAbvGrd", "Fireplaces", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch"]]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score
import seaborn as sb
import matplotlib.pyplot as plt
from IPython.display import Image as PImage
from sklearn.linear_model import LinearRegression

# %%
decision_tree = tree.DecisionTreeClassifier(criterion='entropy',
                                            min_samples_split=20,
                                            min_samples_leaf=5,
                                            max_depth = 2,
                                            class_weight="balanced")
tree = decision_tree.fit(x_train, y_train)

# %%
confusion_matrix(y_train, tree.predict(x_train))
# Out:
# array([[876, 222],
#        [ 36, 326]], dtype=int64)

# %%
#Accuracy
(876+326)/(876+36+326+222)
# Out:
# 0.8232876712328767

# %%
#Especificidad
(876)/(876+222)
# Out:
# 0.7978142076502732

# %%
#Sensitividad
(326)/(326+36)
# Out:
# 0.9005524861878453

# %%
#Valor predicitivo positivo ( Recall)
(326)/(326+222)
# Out:
# 0.5948905109489051

# %%
#Valor predicitivo Negativo ( Presicion)
876/(876+36)
# Out:
# 0.9605263157894737

# %% [markdown]
# # Curva ROC

# %%
probas = tree.predict_proba(x_train)

# %%
from sklearn.metrics import roc_curve, auc

# %%
# Obtener tasas positivas falsas y verdaderas
fpr, tpr, thresholds = roc_curve(y_train, probas[:,0], pos_label=0)
base_fpr, base_tpr, _ = roc_curve(y_train, [1 for _ in range(len(y_train))])
# obtener área debajo de la curva
roc_auc = auc(fpr, tpr)
# PLOT ROC curva
plt.figure(dpi=150)
plt.plot(fpr, tpr, lw=1, color='green', label=f'AUC = {roc_auc:.3f}')
plt.title('ROC Curve for RF classifier')
plt.rcParams['font.size'] = 16
    # Plot both curvas
plt.plot(base_fpr, base_tpr, 'b', label = 'baseline')
plt.legend();

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
y_train = dsn_f['SalePriceBinary'].astype("int")
x_train = dsn_f.loc[:,["TotRmsAbvGrd","GarageArea", "GarageCars","OverallCond","PoolArea","OverallQual","LotArea", "TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "TotRmsAbvGrd", "Fireplaces", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch"]]

Random_F = RandomForestClassifier(n_estimators = 100,max_depth=1, random_state=0)
Random_Fit = Random_F.fit(x_train, y_train)

confusion_matrix(y_train, Random_Fit.predict(x_train))
# Out:
# array([[1093,    5],
#        [ 213,  149]], dtype=int64)

# %%
# Tener importancia
from matplotlib import pyplot
importance = Random_Fit.feature_importances_
# Resumir la importancia de la característica
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot importancia de la trama
plt.figure(dpi=130)
plt.rcParams['font.size'] = 10
plt.barh(x_train.columns, Random_Fit.feature_importances_)
# Out:
# Feature: 0, Score: 0.06000
# Feature: 1, Score: 0.05000
# Feature: 2, Score: 0.12000
# Feature: 3, Score: 0.16000
# Feature: 4, Score: 0.00000
# Feature: 5, Score: 0.00000
# Feature: 6, Score: 0.21000
# Feature: 7, Score: 0.02000
# Feature: 8, Score: 0.13000
# Feature: 9, Score: 0.07000
# Feature: 10, Score: 0.07000
# Feature: 11, Score: 0.01000
# Feature: 12, Score: 0.02000
# Feature: 13, Score: 0.04000
# Feature: 14, Score: 0.00000
# Feature: 15, Score: 0.04000
# Feature: 16, Score: 0.00000
# Feature: 17, Score: 0.00000
# Feature: 18, Score: 0.00000
# <BarContainer object of 19 artists>
